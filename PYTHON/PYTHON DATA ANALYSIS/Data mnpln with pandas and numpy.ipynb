# %%
###  Data manipulation and analysis with pandas--- this provides a wide range of function in data analysis making it easier to clean,transform and extract insights from data

# %%
# %pip install openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/openpyxl/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/openpyxl/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/openpyxl/
# ...

# %%
import pandas as pd

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\user\OneDrive\Desktop\SABIAH DANKANO\PYTHON\PYTHON DATA ANALYSIS

# %%
import os

print("Current folder:", os.getcwd())
print("Files:", os.listdir())
# Out:
# Current folder: c:\Users\user\OneDrive\Desktop\SABIAH DANKANO\PYTHON\PYTHON DATA ANALYSIS
# Files: ['Data mnpln with pandas and numpy.ipynb', 'myexcel.xlsx', 'Numpy.ipynb', 'Pandas.ipynb']

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python314\python.exe

# %%
import importlib.util
print(importlib.util.find_spec("openpyxl"))
# Out:
# None

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import openpyxl
print(openpyxl.__version__)
# Out:
# 3.1.5

# %%
import pandas as pd

df = pd.read_excel("myexcel.xlsx")
df.head()
# Out:
#        Month Financial Year  Fashions Direct     Suburb State  Postcode  \
# 0 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 1 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 2 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 3 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 4 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
#
#      Country        Manager Category           Buyer   Sales  Year     Day  \
# 0  Australia  Jeremy Garcia     Home    Richard Carr  479.02  2016  Friday
# 1  Australia  Jeremy Garcia  Juniors  Chester George  149.95  2016  Friday
# 2  Australia  Jeremy Garcia     Mens    Bruce Curran   14.00  2016  Friday
# 3  Australia  Jeremy Garcia  Juniors  Chester George   12.00  2016  Friday
# 4  Australia  Jeremy Garcia   Womens    Amy Buchanan   46.94  2016  Friday
#
#     Month2
# 0  January
# 1  January
# 2  January
# 3  January
# 4  January

# %%
 ### FECTH THE first 5 rows of the data frame
df.head(5)
# Out:
#        Month Financial Year  Fashions Direct     Suburb State  Postcode  \
# 0 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 1 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 2 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 3 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 4 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
#
#      Country        Manager Category           Buyer   Sales  Year     Day  \
# 0  Australia  Jeremy Garcia     Home    Richard Carr  479.02  2016  Friday
# 1  Australia  Jeremy Garcia  Juniors  Chester George  149.95  2016  Friday
# 2  Australia  Jeremy Garcia     Mens    Bruce Curran   14.00  2016  Friday
# 3  Australia  Jeremy Garcia  Juniors  Chester George   12.00  2016  Friday
# 4  Australia  Jeremy Garcia   Womens    Amy Buchanan   46.94  2016  Friday
#
#     Month2
# 0  January
# 1  January
# 2  January
# 3  January
# 4  January

# %%
df.tail()
# Out:
#         Month Financial Year  Fashions Direct     Suburb State  Postcode  \
# 8  2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 9  2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 10 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 11 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
# 12 2016-01-01        2015/16  Fashions Direct  Chatswood   NSW      2067
#
#       Country        Manager     Category             Buyer  Sales  Year  \
# 8   Australia  Jeremy Garcia         Kids  Elizabeth Gentry   5.00  2016
# 9   Australia  Jeremy Garcia       Womens      Amy Buchanan  87.99  2016
# 10  Australia  Jeremy Garcia         Kids  Elizabeth Gentry   4.00  2016
# 11  Australia  Jeremy Garcia       Womens      Amy Buchanan   5.00  2016
# 12  Australia  Jeremy Garcia  Accessories      Maggie Mayer   2.99  2016
#
#        Day   Month2
# 8   Friday  January
# 9   Friday  January
# 10  Friday  January
# ...

# %%
df.describe() ### the statistical function
# Out:
#                      Month  Postcode       Sales    Year
# count                   13      13.0   13.000000    13.0
# mean   2016-01-01 00:00:00    2067.0   66.592308  2016.0
# min    2016-01-01 00:00:00    2067.0   -2.990000  2016.0
# 25%    2016-01-01 00:00:00    2067.0    5.000000  2016.0
# 50%    2016-01-01 00:00:00    2067.0   14.000000  2016.0
# 75%    2016-01-01 00:00:00    2067.0   46.940000  2016.0
# max    2016-01-01 00:00:00    2067.0  479.020000  2016.0
# std                    NaN       0.0  131.316756     0.0

# %%
df.dtypes
# Out:
# Month              datetime64[us]
# Financial Year                str
# Fashions Direct               str
# Suburb                        str
# State                         str
# Postcode                    int64
# Country                       str
# Manager                       str
# Category                      str
# Buyer                         str
# Sales                     float64
# Year                        int64
# Day                           str
# Month2                        str
# dtype: object

# %%
### Handling missing values

# %%
df.isnull()
# Out:
#     Month  Financial Year  Fashions Direct  Suburb  State  Postcode  Country  \
# 0   False           False            False   False  False     False    False
# 1   False           False            False   False  False     False    False
# 2   False           False            False   False  False     False    False
# 3   False           False            False   False  False     False    False
# 4   False           False            False   False  False     False    False
# 5   False           False            False   False  False     False    False
# 6   False           False            False   False  False     False    False
# 7   False           False            False   False  False     False    False
# 8   False           False            False   False  False     False    False
# 9   False           False            False   False  False     False    False
# 10  False           False            False   False  False     False    False
# ...

# %%
df.isnull().any() ### any missing value
# Out:
# Month              False
# Financial Year     False
# Fashions Direct    False
# Suburb             False
# State              False
# Postcode           False
# Country            False
# Manager            False
# Category           False
# Buyer              False
# Sales              False
# Year               False
# Day                False
# Month2             False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Month              0
# Financial Year     0
# Fashions Direct    0
# Suburb             0
# State              0
# Postcode           0
# Country            0
# Manager            0
# Category           0
# Buyer              0
# Sales              0
# Year               0
# Day                0
# Month2             0
# dtype: int64
