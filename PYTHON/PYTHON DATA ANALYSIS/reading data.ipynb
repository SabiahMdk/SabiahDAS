# %%
import pandas as pd
from io import StringIO
Data ='[{ "employer_name":"Jackson","email":"jackson@gmail.com","job profile":"Data analyst"}]'
df=pd.read_json(StringIO(Data))

# %%
df
# Out:
#   employer_name              email   job profile
# 0       Jackson  jackson@gmail.com  Data analyst

# %%
df.to_json()
# Out:
# '{"employer_name":{"0":"Jackson"},"email":{"0":"jackson@gmail.com"},"job profile":{"0":"Data analyst"}}'

# %%
df=pd.read_csv("enter a url from any data source",header=None)
