# %% [markdown]
# #### STATISTICS isa fluid that deals with collection,organization,analysis,interpretation and presentation of Data
#
# ### TYPES
# -DESCRIPTIVE
# -INFERENTIAL
#
# -Descriptive --- Organizing and summarizing of data e.g mean,mode,median,variance and standard deviation
# -Inferential----collecction  of data and conclusion on inference through some experiment collected e.g Sample data

# %% [markdown]
# ##### MEASURES OF DISPERSION ---Variance and Standard Deviation

# %% [markdown]
# ##### MEASURES OF CENTRAL TENDENCY---mean,mode and mediank

# %% [markdown]
# VARIABLE---- this is a property that can take up any
#
#
# ###TYPES
#
#
# Quantitative---discrete and continous
#
# Qualitatuve/Categorical--- Gnder(male,female), colors (red,blue,etc)

# %% [markdown]
# ##### RANDOM VARIBALE ---- A function whose value are derived from different process or experiment
#
# #### TYPES OF RV
# ##### Discrete ----tosing a coin,rolling a dice
# ##### Continous Random Variable --- tomorrow has many inches it is going to rain

# %% [markdown]
# #### THE 5 Numbers Summary
# #####  1 -Minimun
# ##### 2- 1st Quater (25%)
# ##### 3 - Median
# ##### 4 - 3rd Quater (75%)
# ##### 5 - Maximum

# %% [markdown]
# ##### COVARIANCE and CORRELATION
# ##### They are Statistical Measures used to determine the relationship between two Variables
# ##### COVARIANCE--- This is the measure of how much 2 random variable change together,if the increase or decrease together,it is positive.
# ##### COREELATION ----1-Pearson Correlation coefficient
# #####                 2- Speaman Rank Coefficient
