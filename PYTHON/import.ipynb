# %%
####  in python,modulus and packages helps to organize amd reuse code.

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print (sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
sqrt(16)
print (pi)
# Out:
# 3.141592653589793

# %%
import os
print (os.getcwd())
# Out:
# c:\Users\user\OneDrive\Desktop\SABIAH DANKANO\PYTHON

# %%
import sys
sys.path.append(r"C:\users\user\oneDrive\SabiahDankano python")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\user\\OneDrive\\Desktop\\SABIAH DANKANO\\PYTHON'

# %%
import os


print (os.getcwd())
print (os.listdir())
# Out:
# c:\Users\user\OneDrive\Desktop\SABIAH DANKANO\PYTHON
# ['import.ipynb', 'pytbscss']

# %%
from packages.maths import addition
addition(2,9)
# Out:
# 11

# %%
from packages import maths
maths.addition (6,7)
# Out:
# 13

# %%
from packages.maths import addition
print (addition(5,7))
# Out:
# 12
