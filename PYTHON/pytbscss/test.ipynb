# %%
print ("hello world")
# Out:
# hello world

# %%
print ("hello")
# Out:
# hello

# %%
a = 100

# %%
age = 33
weight = 78
name="Keleci"
is_human=True

print ("age :",age)
print("weight :",weight)
print ("name:",name)
# Out:
# age : 33
# weight : 78
# name: Keleci

# %%
## naming conventions
## variables should be description
## variables should contains letter,number or underscore
## variable names are case sensitative

first_name="kola"
last_name="martins"

# %%
## case sensitivity
name ="Anah"
Name ="anah"


name == Name
# Out:
# False

# %%
##understanding variable types,python is dynamically typed e.g

age = 33 
weight = 78.9
name="Keleci"
is_human=True
print (type(weight))
# Out:
# <class 'float'>

# %%
##type conversion

age = 44
print(type(age))

age_str=str(age)
print (age_str)
print (type(age_str))

weight = 78.9
print (type(weight))
int(weight) #### it will remove the decimal
float(int(weight))
# Out:
# <class 'int'>
# 44
# <class 'str'>
# <class 'float'>
# 78.0

# %%
## dynamic typing ..... you dont need to declare or specify the data type of a variable 
var = 34
print(var,type(var))
var = "hello"
print(var,type(var))
var = 90.0
print(var,type(var))
# Out:
# 34 <class 'int'>
# hello <class 'str'>
# 90.0 <class 'float'>

# %%
##input 
age = input("what is the age")
print(age,type(age))
# Out:
# 34 <class 'str'>

# %%
## DATA TYPES -These are classifications of data that tell an interpreter or a compiller how the programmer intends to use data

## interger
age = 34
type(age)
# Out:
# int

# %%
## float
height = 34.5
print (height)
print (type(height))

## string
name = 'tolani'
print (type(name))
#boolean --- this defines true or false
a=45
b=8
a==4
a=5
b=5
a==b
# Out:
# 34.5
# <class 'float'>
# <class 'str'>
# True

# %%
##common erroes
name = "ella" + str(8)
print (name)
# Out:
# ella8

# %%
##OPERATORS
a =8
b =97
a + b

a =9
b = 5
result = a + b
print (result)
# Out:
# 14

# %%
a= 12
b = 9

add_result = a +b
sub_result = a -b
mult_result = a * b
div_result = a/b
floor_div_result = a//b
modulus_result =a % b
add_result = a +b
print (add_result)
print (sub_result)
print (mult_result)
print (floor_div_result)
print(modulus_result)
print(add_result )

12//7
12 % 7
# Out:
# 21
# 3
# 108
# 1
# 3
# 21
# 5

# %%
 ## comparision operation
num1 = 9
num2 = 6
num1< num2


print  (num1> num2)
# Out:
# True

# %%
##logical operation
#and,or, not
# and -borh must be true
# or----at least one true
# not --- reverse the result

a = True
b = True
a and b
# Out:
# True

# %%
a = True
b = False

a or b
# Out:
# True

# %%
a = 5

print ( a > 4 )

print (a > 4 and a < 2)
print (a > 4 or a < 2)
# Out:
# True
# False
# True
